# %%
from typing import *

import hkkang_utils.file as file_utils

# %%
# Load query
query_path = "/root/ColBERT/data/msmarco/queries.train.tsv"
query_dict: List[Tuple[str, str]] = file_utils.read_csv_file(query_path, delimiter="\t", first_row_as_header=False)
query_dict: Dict[int, str] = {int(row[0]): row[1] for row in query_dict}

# %%
# Load document collection
corpus_path = "/root/ColBERT/data/msmarco/collection.tsv"
corpus: List[Tuple[str, str]] = file_utils.read_csv_file(corpus_path, delimiter="\t", first_row_as_header=False)
corpus: Dict[int, str] = {int(pid): text for pid, text in corpus}

# %%
qid=1185869
print(query_dict[qid])

# %%
pid = 0
print(corpus[pid])
# Out:
# The presence of communication amid scientific minds was equally important to the success of the Manhattan Project as scientific intellect was. The only cloud hanging over the impressive achievement of the atomic researchers and engineers is what their success truly meant; hundreds of thousands of innocent lives obliterated.

# %%
pid = 5154065
print(corpus[pid])
# Out:
# Communication contributed as much to the success of the Manhattan Project as did scientific discovery. Although the creation of the first atomic weapon was clearly a technological triumph, the question of morality and responsibility to ethics will forever plague the topic.
